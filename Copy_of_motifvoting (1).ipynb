# %%
#import statements and data entry

import pandas as pd
df = pd.read_csv('/content/motiftattoo.csv')
df.head()
# Out:
#   Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.  \
# 0
# 1                             popsysplants@gmail.com
# 2
# 3
# 4                           thegabrielgang@yahoo.com
#
#   ANIMAL (Choice 1) ANIMAL (Choice 2) ANIMAL (Choice 3) ANIMAL (Choice 4)  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN          Choice 2               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3          Choice 1               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#   ANIMAL (Choice 5) ANIMAL (Choice 6) ANIMAL (Choice 7) ANIMAL (Choice 8)  \
# 0               NaN          Choice 6               NaN          Choice 8
# ...

# %%
#finding duplicates and people who did not submit an email address

dupnosub = df[df.duplicated(['Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.', 'IP'])]
dupnosub.head()
# Out:
#    Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.  \
# 3
# 8
# 11                                 Kimity23@gmail.com
# 12                                 Kimity23@gmail.com
# 16
#
#    ANIMAL (Choice 1) ANIMAL (Choice 2) ANIMAL (Choice 3) ANIMAL (Choice 4)  \
# 3           Choice 1               NaN               NaN               NaN
# 8                NaN               NaN               NaN               NaN
# 11               NaN               NaN               NaN               NaN
# 12          Choice 1               NaN               NaN               NaN
# 16               NaN               NaN               NaN               NaN
#
#    ANIMAL (Choice 5) ANIMAL (Choice 6) ANIMAL (Choice 7) ANIMAL (Choice 8)  \
# 3                NaN               NaN               NaN               NaN
# ...

# %%
#removing non-submissions

duplicates = dupnosub[dupnosub['Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.'] != ' ']
duplicates.head()
# Out:
#    Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.  \
# 11                                 Kimity23@gmail.com
# 12                                 Kimity23@gmail.com
# 19                            Gregashtattoo@gmail.com
# 23                            Gregashtattoo@gmail.com
# 36                                Reneash88@gmail.com
#
#    ANIMAL (Choice 1) ANIMAL (Choice 2) ANIMAL (Choice 3) ANIMAL (Choice 4)  \
# 11               NaN               NaN               NaN               NaN
# 12          Choice 1               NaN               NaN               NaN
# 19               NaN               NaN               NaN               NaN
# 23          Choice 1               NaN               NaN               NaN
# 36               NaN               NaN               NaN               NaN
#
# ...

# %%
#drop duplicates for email and IP address
#note: this seems unreasonable, especially the IP address part, as it could still be different people voting

nodup = df.drop_duplicates(subset = ['Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.', 'IP'])
nodup.head()

#the return on this is strange, as it does not remove all instances of duplicates in the email space...
# Out:
#   Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.  \
# 0
# 1                             popsysplants@gmail.com
# 2
# 4                           thegabrielgang@yahoo.com
# 5                           Pinuppoetjakii@gmail.com
#
#   ANIMAL (Choice 1) ANIMAL (Choice 2) ANIMAL (Choice 3) ANIMAL (Choice 4)  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN          Choice 2               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
# 5               NaN               NaN               NaN               NaN
#
#   ANIMAL (Choice 5) ANIMAL (Choice 6) ANIMAL (Choice 7) ANIMAL (Choice 8)  \
# ...

# %%
#drop duplicates for only email

noemaildup = df.drop_duplicates(subset = 'Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.')
noemaildup.head()

# making the previous results more strange, as this one actually works
# Out:
#   Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.  \
# 0
# 1                             popsysplants@gmail.com
# 4                           thegabrielgang@yahoo.com
# 5                           Pinuppoetjakii@gmail.com
# 7                              Mattmozzone@gmail.com
#
#   ANIMAL (Choice 1) ANIMAL (Choice 2) ANIMAL (Choice 3) ANIMAL (Choice 4)  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN          Choice 2               NaN               NaN
# 4               NaN               NaN               NaN               NaN
# 5               NaN               NaN               NaN               NaN
# 7               NaN               NaN               NaN          Choice 4
#
#   ANIMAL (Choice 5) ANIMAL (Choice 6) ANIMAL (Choice 7) ANIMAL (Choice 8)  \
# ...

# %%
#sorts the dataset with no email duplicates by IP address
nedsorted = noemaildup.sort_values(by = ['IP'])
nedsorted.head()
# Out:
#      Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.  \
# 1309                                   Katv93@gmail.com
# 404                                    Katv93@yahoo.com
# 1460                             Mattberard92@ymail.com
# 1786                             Gilspinklady@gmail.com
# 188                          Shields.jacquia@icloud.com
#
#      ANIMAL (Choice 1) ANIMAL (Choice 2) ANIMAL (Choice 3) ANIMAL (Choice 4)  \
# 1309               NaN               NaN               NaN               NaN
# 404                NaN               NaN               NaN               NaN
# 1460               NaN               NaN               NaN          Choice 4
# 1786               NaN               NaN               NaN               NaN
# 188                NaN               NaN               NaN               NaN
#
# ...

# %%
#for looking at duplicate IP addresses of people who used different emails
noedupip = noemaildup.duplicated(subset='IP')
noedupip.all

#this just gives you an indication of all the values
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of 0       False
# 1        True
# 4       False
# 5       False
# 7       False
#         ...
# 2251     True
# 2252    False
# 2253    False
# 2254    False
# 2255    False
# Length: 1331, dtype: bool>

# %%
#finding a list of all the values where the ip address is the same
noedupipt = noedupip[noedupip].index
noedupipt.all

#this is terrible/impossible to read
# Out:
# <bound method Index.all of Index([   1,   10,   13,   14,   17,   21,   22,   24,   25,   29,
#        ...
#        2116, 2135, 2145, 2147, 2149, 2163, 2198, 2211, 2233, 2251],
#       dtype='int64', length=827)>

# %%
#for totalling up the votes of each group
totals = noemaildup.notna().sum()
# Out:
# Your email: We use this, along with other computery-magic tricks, to limit the voting to one per person. We ask that you please respect this and just vote once.Thank you, and thanks for caring about art in RI.    1331
# ANIMAL (Choice 1)                                                                                                                                                                                                     333
# ANIMAL (Choice 2)                                                                                                                                                                                                      79
# ANIMAL (Choice 3)                                                                                                                                                                                                      28
# ...

# %%
#exporting (MAKE SURE TO CHECK WHICH DATAFRAME YOU EXPORT!!!!!)

#to csv : nedsorted.to_csv('motifvotingnew.csv', index=False)
#to excel : nedsorted.to_excel('motifvotingnew.xls', index=False)

#totals to csv: totals.to_csv('totals.csv')
